# %%
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from nba_api.stats.endpoints import shotchartdetail

# %%
players = json.loads(requests.get('https://raw.githubusercontent.com/bttmly/nba/master/data/players.json').text)
teams = json.loads(requests.get('https://raw.githubusercontent.com/bttmly/nba/master/data/teams.json').text)

# %%
def get_player_id(first, last):
    for player in players:
        if player['firstName'] == first and player['lastName'] == last:
            return player['playerId']
    return -1

# %%
def get_team_id(team_name):
    for team in teams:
        if team['teamName'] == team_name:
            return team['teamId']
    return -1

# %%
shot_json = shotchartdetail.ShotChartDetail(
            team_id = get_team_id('Golden State Warriors'),
            player_id = get_player_id('Stephen', 'Curry'),
            context_measure_simple = 'FGA',
            season_nullable = '2020-21',
            season_type_all_star = 'Regular Season')

shot_data = json.loads(shot_json.get_json())

# %%
relevant_data = shot_data['resultSets'][0]
headers = relevant_data['headers']
rows = relevant_data['rowSet']

# %%
curry = pd.DataFrame(rows)
curry.columns = headers

display(curry)
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 0    Shot Chart Detail  0022000001             21     201939  Stephen Curry
# 1    Shot Chart Detail  0022000001             29     201939  Stephen Curry
# 2    Shot Chart Detail  0022000001             81     201939  Stephen Curry
# 3    Shot Chart Detail  0022000001             97     201939  Stephen Curry
# 4    Shot Chart Detail  0022000001            152     201939  Stephen Curry
# ..                 ...         ...            ...        ...            ...
# 126  Shot Chart Detail  0022000092            625     201939  Stephen Curry
# 127  Shot Chart Detail  0022000092            637     201939  Stephen Curry
# 128  Shot Chart Detail  0022000092            671     201939  Stephen Curry
# 129  Shot Chart Detail  0022000092            722     201939  Stephen Curry
# 130  Shot Chart Detail  0022000092            726     201939  Stephen Curry
#
#         TEAM_ID              TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0    1610612744  Golden State Warriors       1                 10
# 1    1610612744  Golden State Warriors       1                  9
# 2    1610612744  Golden State Warriors       1                  6
# 3    1610612744  Golden State Warriors       1                  4
# 4    1610612744  Golden State Warriors       1                  1
# ..          ...                    ...     ...                ...
# 126  1610612744  Golden State Warriors       4                  5
# 127  1610612744  Golden State Warriors       4                  5
# 128  1610612744  Golden State Warriors       4                  3
# 129  1610612744  Golden State Warriors       4                  1
# 130  1610612744  Golden State Warriors       4                  0
#
#      SECONDS_REMAINING  ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                   16  ...   Left Side Center(LC)          24+ ft.
# 1                   38  ...              Center(C)  Less Than 8 ft.
# 2                   15  ...   Left Side Center(LC)          24+ ft.
# 3                   52  ...  Right Side Center(RC)        16-24 ft.
# 4                   37  ...              Center(C)  Less Than 8 ft.
# ..                 ...  ...                    ...              ...
# 126                 48  ...  Right Side Center(RC)        16-24 ft.
# 127                 14  ...   Left Side Center(LC)        16-24 ft.
# 128                  8  ...  Right Side Center(RC)          24+ ft.
# 129                  6  ...   Left Side Center(LC)          24+ ft.
# 130                 42  ...   Left Side Center(LC)          24+ ft.
#
#     SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0              26  -120   240                   1               0   20201222
# 1               3    29    26                   1               1   20201222
# 2              24   -90   231                   1               0   20201222
# 3              22    72   215                   1               1   20201222
# 4               2     1    26                   1               0   20201222
# ..            ...   ...   ...                 ...             ...        ...
# 126            17    92   146                   1               1   20210103
# 127            21  -166   139                   1               0   20210103
# 128            25   128   226                   1               0   20210103
# 129            26  -128   235                   1               1   20210103
# 130            26  -211   164                   1               1   20210103
#
#      HTM  VTM
# 0    BKN  GSW
# 1    BKN  GSW
# 2    BKN  GSW
# 3    BKN  GSW
# 4    BKN  GSW
# ..   ...  ...
# 126  GSW  POR
# 127  GSW  POR
# 128  GSW  POR
# 129  GSW  POR
# 130  GSW  POR
#
# [131 rows x 24 columns]

# %%
curry = curry.loc[curry['GAME_ID'] == '0022000092']

display(curry)
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 100  Shot Chart Detail  0022000092             17     201939  Stephen Curry
# 101  Shot Chart Detail  0022000092             49     201939  Stephen Curry
# 102  Shot Chart Detail  0022000092             62     201939  Stephen Curry
# 103  Shot Chart Detail  0022000092             72     201939  Stephen Curry
# 104  Shot Chart Detail  0022000092             99     201939  Stephen Curry
# 105  Shot Chart Detail  0022000092            103     201939  Stephen Curry
# 106  Shot Chart Detail  0022000092            113     201939  Stephen Curry
# 107  Shot Chart Detail  0022000092            117     201939  Stephen Curry
# 108  Shot Chart Detail  0022000092            141     201939  Stephen Curry
# 109  Shot Chart Detail  0022000092            157     201939  Stephen Curry
# 110  Shot Chart Detail  0022000092            161     201939  Stephen Curry
# 111  Shot Chart Detail  0022000092            296     201939  Stephen Curry
# 112  Shot Chart Detail  0022000092            305     201939  Stephen Curry
# 113  Shot Chart Detail  0022000092            310     201939  Stephen Curry
# 114  Shot Chart Detail  0022000092            313     201939  Stephen Curry
# 115  Shot Chart Detail  0022000092            320     201939  Stephen Curry
# 116  Shot Chart Detail  0022000092            348     201939  Stephen Curry
# 117  Shot Chart Detail  0022000092            366     201939  Stephen Curry
# 118  Shot Chart Detail  0022000092            439     201939  Stephen Curry
# 119  Shot Chart Detail  0022000092            462     201939  Stephen Curry
# 120  Shot Chart Detail  0022000092            480     201939  Stephen Curry
# 121  Shot Chart Detail  0022000092            495     201939  Stephen Curry
# 122  Shot Chart Detail  0022000092            516     201939  Stephen Curry
# 123  Shot Chart Detail  0022000092            524     201939  Stephen Curry
# 124  Shot Chart Detail  0022000092            618     201939  Stephen Curry
# 125  Shot Chart Detail  0022000092            621     201939  Stephen Curry
# 126  Shot Chart Detail  0022000092            625     201939  Stephen Curry
# 127  Shot Chart Detail  0022000092            637     201939  Stephen Curry
# 128  Shot Chart Detail  0022000092            671     201939  Stephen Curry
# 129  Shot Chart Detail  0022000092            722     201939  Stephen Curry
# 130  Shot Chart Detail  0022000092            726     201939  Stephen Curry
#
#         TEAM_ID              TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 100  1610612744  Golden State Warriors       1                 10
# 101  1610612744  Golden State Warriors       1                  8
# 102  1610612744  Golden State Warriors       1                  6
# 103  1610612744  Golden State Warriors       1                  6
# 104  1610612744  Golden State Warriors       1                  4
# 105  1610612744  Golden State Warriors       1                  4
# 106  1610612744  Golden State Warriors       1                  4
# 107  1610612744  Golden State Warriors       1                  3
# 108  1610612744  Golden State Warriors       1                  1
# 109  1610612744  Golden State Warriors       1                  1
# 110  1610612744  Golden State Warriors       1                  0
# 111  1610612744  Golden State Warriors       2                  4
# 112  1610612744  Golden State Warriors       2                  4
# 113  1610612744  Golden State Warriors       2                  3
# 114  1610612744  Golden State Warriors       2                  3
# 115  1610612744  Golden State Warriors       2                  3
# 116  1610612744  Golden State Warriors       2                  1
# 117  1610612744  Golden State Warriors       2                  0
# 118  1610612744  Golden State Warriors       3                  6
# 119  1610612744  Golden State Warriors       3                  4
# 120  1610612744  Golden State Warriors       3                  3
# 121  1610612744  Golden State Warriors       3                  2
# 122  1610612744  Golden State Warriors       3                  0
# 123  1610612744  Golden State Warriors       3                  0
# 124  1610612744  Golden State Warriors       4                  6
# 125  1610612744  Golden State Warriors       4                  6
# 126  1610612744  Golden State Warriors       4                  5
# 127  1610612744  Golden State Warriors       4                  5
# 128  1610612744  Golden State Warriors       4                  3
# 129  1610612744  Golden State Warriors       4                  1
# 130  1610612744  Golden State Warriors       4                  0
#
#      SECONDS_REMAINING  ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 100                 46  ...  Right Side Center(RC)        16-24 ft.
# 101                  0  ...              Center(C)  Less Than 8 ft.
# 102                 45  ...              Center(C)  Less Than 8 ft.
# 103                 11  ...   Left Side Center(LC)          24+ ft.
# 104                 55  ...              Center(C)  Less Than 8 ft.
# 105                 50  ...  Right Side Center(RC)          24+ ft.
# 106                 17  ...              Center(C)  Less Than 8 ft.
# 107                 48  ...              Center(C)          24+ ft.
# 108                 57  ...   Left Side Center(LC)          24+ ft.
# 109                 16  ...  Right Side Center(RC)          24+ ft.
# 110                 40  ...              Center(C)  Less Than 8 ft.
# 111                 35  ...              Center(C)  Less Than 8 ft.
# 112                 15  ...   Left Side Center(LC)          24+ ft.
# 113                 42  ...              Center(C)          24+ ft.
# 114                 18  ...              Center(C)  Less Than 8 ft.
# 115                  4  ...  Right Side Center(RC)        16-24 ft.
# 116                  8  ...              Center(C)  Less Than 8 ft.
# 117                  1  ...          Right Side(R)         8-16 ft.
# 118                 17  ...              Center(C)  Less Than 8 ft.
# 119                 48  ...  Right Side Center(RC)          24+ ft.
# 120                 38  ...   Left Side Center(LC)          24+ ft.
# 121                 15  ...          Right Side(R)          24+ ft.
# 122                 57  ...              Center(C)         8-16 ft.
# 123                 23  ...  Right Side Center(RC)          24+ ft.
# 124                 49  ...   Left Side Center(LC)          24+ ft.
# 125                 20  ...  Right Side Center(RC)          24+ ft.
# 126                 48  ...  Right Side Center(RC)        16-24 ft.
# 127                 14  ...   Left Side Center(LC)        16-24 ft.
# 128                  8  ...  Right Side Center(RC)          24+ ft.
# 129                  6  ...   Left Side Center(LC)          24+ ft.
# 130                 42  ...   Left Side Center(LC)          24+ ft.
#
#     SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 100            21   155   152                   1               1   20210103
# 101             3     5    37                   1               1   20210103
# 102             7    -3    73                   1               0   20210103
# 103            26  -155   211                   1               1   20210103
# 104             6    67     7                   1               1   20210103
# 105            26   122   239                   1               0   20210103
# 106             2     6    25                   1               1   20210103
# 107            27    29   274                   1               0   20210103
# 108            31  -101   296                   1               0   20210103
# 109            26   143   221                   1               1   20210103
# 110             3   -20    29                   1               1   20210103
# 111             6    -5    63                   1               1   20210103
# 112            27  -137   236                   1               0   20210103
# 113            26    52   263                   1               1   20210103
# 114             1    -3    18                   1               1   20210103
# 115            21   150   155                   1               0   20210103
# 116             3    21    23                   1               0   20210103
# 117             9    51    76                   1               0   20210103
# 118             0     0     0                   1               1   20210103
# 119            28   114   260                   1               1   20210103
# 120            24  -200   136                   1               0   20210103
# 121            24   234    78                   1               0   20210103
# 122            11    -9   110                   1               1   20210103
# 123            28   119   258                   1               1   20210103
# 124            25  -182   176                   1               1   20210103
# 125            29   159   243                   1               0   20210103
# 126            17    92   146                   1               1   20210103
# 127            21  -166   139                   1               0   20210103
# 128            25   128   226                   1               0   20210103
# 129            26  -128   235                   1               1   20210103
# 130            26  -211   164                   1               1   20210103
#
#      HTM  VTM
# 100  GSW  POR
# 101  GSW  POR
# 102  GSW  POR
# 103  GSW  POR
# 104  GSW  POR
# 105  GSW  POR
# 106  GSW  POR
# 107  GSW  POR
# 108  GSW  POR
# 109  GSW  POR
# 110  GSW  POR
# 111  GSW  POR
# 112  GSW  POR
# 113  GSW  POR
# 114  GSW  POR
# 115  GSW  POR
# 116  GSW  POR
# 117  GSW  POR
# 118  GSW  POR
# 119  GSW  POR
# 120  GSW  POR
# 121  GSW  POR
# 122  GSW  POR
# 123  GSW  POR
# 124  GSW  POR
# 125  GSW  POR
# 126  GSW  POR
# 127  GSW  POR
# 128  GSW  POR
# 129  GSW  POR
# 130  GSW  POR
#
# [31 rows x 24 columns]

# %%
def create_court(ax, color):
    
    ax.plot([-220, -220], [0, 140], linewidth=2, color=color)
    ax.plot([220, 220], [0, 140], linewidth=2, color=color)
    
    ax.add_artist(mpl.patches.Arc((0, 140), 440, 315, theta1=0, theta2=180, facecolor='none', edgecolor=color, lw=2))
    
    ax.plot([-80, -80], [0, 190], linewidth=2, color=color)
    ax.plot([80, 80], [0, 190], linewidth=2, color=color)
    ax.plot([-60, -60], [0, 190], linewidth=2, color=color)
    ax.plot([60, 60], [0, 190], linewidth=2, color=color)
    ax.plot([-80, 80], [190, 190], linewidth=2, color=color)
    ax.add_artist(mpl.patches.Circle((0, 190), 60, facecolor='none', edgecolor=color, lw=2))
    
    ax.add_artist(mpl.patches.Circle((0, 60), 15, facecolor='none', edgecolor=color, lw=2))
    
    ax.plot([-30, 30], [40, 40], linewidth=2, color=color)
    
    ax.set_xticks([])
    ax.set_yticks([])
    
    ax.set_xlim(-250, 250)
    ax.set_ylim(0, 470)
    
    return ax

# %%
fig = plt.figure(figsize=(4, 3.76))
ax = fig.add_axes([0, 0, 1, 1])
ax = create_court(ax, 'black')
ax.scatter(curry['LOC_X'], curry['LOC_Y'] + 60)

plt.show()
