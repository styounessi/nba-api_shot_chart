# %%
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from nba_api.stats.endpoints import shotchartdetail

# %%
players = json.loads(requests.get('https://raw.githubusercontent.com/bttmly/nba/master/data/players.json').text)
teams = json.loads(requests.get('https://raw.githubusercontent.com/bttmly/nba/master/data/teams.json').text)

# %%
def player_id(first, last):
    for player in players:
        if player['firstName'] == first and player['lastName'] == last:
            return player['playerId']
    return -1

def team_id(team_name):
    for team in teams:
        if team['teamName'] == team_name:
            return team['teamId']
    return -1

# %%
shot_json = shotchartdetail.ShotChartDetail(
            team_id = team_id('Golden State Warriors'),
            player_id = player_id('Stephen', 'Curry'),
            context_measure_simple = 'FGA',
            season_nullable = '2020-21',
            season_type_all_star = 'Regular Season')

shot_data = json.loads(shot_json.get_json())
needed_data = shot_data['resultSets'][0]
headers = needed_data['headers']
rows = needed_data['rowSet']

# %%
curry = pd.DataFrame(rows)
curry.columns = headers

display(curry)
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 0    Shot Chart Detail  0022000001             21     201939  Stephen Curry
# 1    Shot Chart Detail  0022000001             29     201939  Stephen Curry
# 2    Shot Chart Detail  0022000001             81     201939  Stephen Curry
# 3    Shot Chart Detail  0022000001             97     201939  Stephen Curry
# 4    Shot Chart Detail  0022000001            152     201939  Stephen Curry
# ..                 ...         ...            ...        ...            ...
# 850  Shot Chart Detail  0022000759            647     201939  Stephen Curry
# 851  Shot Chart Detail  0022000759            662     201939  Stephen Curry
# 852  Shot Chart Detail  0022000759            678     201939  Stephen Curry
# 853  Shot Chart Detail  0022000759            695     201939  Stephen Curry
# 854  Shot Chart Detail  0022000759            714     201939  Stephen Curry
#
#         TEAM_ID              TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0    1610612744  Golden State Warriors       1                 10
# 1    1610612744  Golden State Warriors       1                  9
# 2    1610612744  Golden State Warriors       1                  6
# 3    1610612744  Golden State Warriors       1                  4
# 4    1610612744  Golden State Warriors       1                  1
# ..          ...                    ...     ...                ...
# 850  1610612744  Golden State Warriors       4                  2
# 851  1610612744  Golden State Warriors       4                  1
# 852  1610612744  Golden State Warriors       4                  0
# 853  1610612744  Golden State Warriors       4                  0
# 854  1610612744  Golden State Warriors       4                  0
#
#      SECONDS_REMAINING  ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                   16  ...   Left Side Center(LC)          24+ ft.
# 1                   38  ...              Center(C)  Less Than 8 ft.
# 2                   15  ...   Left Side Center(LC)          24+ ft.
# 3                   52  ...  Right Side Center(RC)        16-24 ft.
# 4                   37  ...              Center(C)  Less Than 8 ft.
# ..                 ...  ...                    ...              ...
# 850                 38  ...              Center(C)          24+ ft.
# 851                 42  ...              Center(C)          24+ ft.
# 852                 32  ...              Center(C)  Less Than 8 ft.
# 853                 16  ...   Left Side Center(LC)          24+ ft.
# 854                  2  ...   Left Side Center(LC)          24+ ft.
#
#     SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0              26  -120   240                   1               0   20201222
# 1               3    29    26                   1               1   20201222
# 2              24   -90   231                   1               0   20201222
# 3              22    72   215                   1               1   20201222
# 4               2     1    26                   1               0   20201222
# ..            ...   ...   ...                 ...             ...        ...
# 850            26   -41   265                   1               1   20210404
# 851            24    31   246                   1               0   20210404
# 852             1     4    15                   1               1   20210404
# 853            26  -186   191                   1               0   20210404
# 854            26  -125   237                   1               0   20210404
#
#      HTM  VTM
# 0    BKN  GSW
# 1    BKN  GSW
# 2    BKN  GSW
# 3    BKN  GSW
# 4    BKN  GSW
# ..   ...  ...
# 850  ATL  GSW
# 851  ATL  GSW
# 852  ATL  GSW
# 853  ATL  GSW
# 854  ATL  GSW
#
# [855 rows x 24 columns]

# %%
curry = curry.loc[curry['GAME_ID'] == '0022000759']

display(curry)
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 832  Shot Chart Detail  0022000759             52     201939  Stephen Curry
# 833  Shot Chart Detail  0022000759            117     201939  Stephen Curry
# 834  Shot Chart Detail  0022000759            142     201939  Stephen Curry
# 835  Shot Chart Detail  0022000759            164     201939  Stephen Curry
# 836  Shot Chart Detail  0022000759            250     201939  Stephen Curry
# 837  Shot Chart Detail  0022000759            285     201939  Stephen Curry
# 838  Shot Chart Detail  0022000759            304     201939  Stephen Curry
# 839  Shot Chart Detail  0022000759            316     201939  Stephen Curry
# 840  Shot Chart Detail  0022000759            320     201939  Stephen Curry
# 841  Shot Chart Detail  0022000759            369     201939  Stephen Curry
# 842  Shot Chart Detail  0022000759            437     201939  Stephen Curry
# 843  Shot Chart Detail  0022000759            444     201939  Stephen Curry
# 844  Shot Chart Detail  0022000759            460     201939  Stephen Curry
# 845  Shot Chart Detail  0022000759            463     201939  Stephen Curry
# 846  Shot Chart Detail  0022000759            486     201939  Stephen Curry
# 847  Shot Chart Detail  0022000759            499     201939  Stephen Curry
# 848  Shot Chart Detail  0022000759            528     201939  Stephen Curry
# 849  Shot Chart Detail  0022000759            617     201939  Stephen Curry
# 850  Shot Chart Detail  0022000759            647     201939  Stephen Curry
# 851  Shot Chart Detail  0022000759            662     201939  Stephen Curry
# 852  Shot Chart Detail  0022000759            678     201939  Stephen Curry
# 853  Shot Chart Detail  0022000759            695     201939  Stephen Curry
# 854  Shot Chart Detail  0022000759            714     201939  Stephen Curry
#
#         TEAM_ID              TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 832  1610612744  Golden State Warriors       1                  8
# 833  1610612744  Golden State Warriors       1                  4
# 834  1610612744  Golden State Warriors       1                  2
# 835  1610612744  Golden State Warriors       1                  0
# 836  1610612744  Golden State Warriors       2                  5
# 837  1610612744  Golden State Warriors       2                  3
# 838  1610612744  Golden State Warriors       2                  1
# 839  1610612744  Golden State Warriors       2                  1
# 840  1610612744  Golden State Warriors       2                  0
# 841  1610612744  Golden State Warriors       3                 10
# 842  1610612744  Golden State Warriors       3                  5
# 843  1610612744  Golden State Warriors       3                  4
# 844  1610612744  Golden State Warriors       3                  3
# 845  1610612744  Golden State Warriors       3                  3
# 846  1610612744  Golden State Warriors       3                  2
# 847  1610612744  Golden State Warriors       3                  1
# 848  1610612744  Golden State Warriors       3                  0
# 849  1610612744  Golden State Warriors       4                  5
# 850  1610612744  Golden State Warriors       4                  2
# 851  1610612744  Golden State Warriors       4                  1
# 852  1610612744  Golden State Warriors       4                  0
# 853  1610612744  Golden State Warriors       4                  0
# 854  1610612744  Golden State Warriors       4                  0
#
#      SECONDS_REMAINING  ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 832                 44  ...              Center(C)          24+ ft.
# 833                  2  ...   Left Side Center(LC)          24+ ft.
# 834                  6  ...              Center(C)         8-16 ft.
# 835                 29  ...   Left Side Center(LC)          24+ ft.
# 836                 41  ...              Center(C)  Less Than 8 ft.
# 837                 14  ...              Center(C)         8-16 ft.
# 838                 41  ...   Left Side Center(LC)        16-24 ft.
# 839                 24  ...              Center(C)  Less Than 8 ft.
# 840                 57  ...              Center(C)  Less Than 8 ft.
# 841                 35  ...              Center(C)  Less Than 8 ft.
# 842                 20  ...          Right Side(R)         8-16 ft.
# 843                 57  ...  Right Side Center(RC)          24+ ft.
# 844                 48  ...          Right Side(R)        16-24 ft.
# 845                 31  ...   Left Side Center(LC)          24+ ft.
# 846                  8  ...              Center(C)  Less Than 8 ft.
# 847                 45  ...              Center(C)          24+ ft.
# 848                  2  ...  Right Side Center(RC)          24+ ft.
# 849                 24  ...  Right Side Center(RC)          24+ ft.
# 850                 38  ...              Center(C)          24+ ft.
# 851                 42  ...              Center(C)          24+ ft.
# 852                 32  ...              Center(C)  Less Than 8 ft.
# 853                 16  ...   Left Side Center(LC)          24+ ft.
# 854                  2  ...   Left Side Center(LC)          24+ ft.
#
#     SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 832            25     6   250                   1               0   20210404
# 833            27   -89   256                   1               0   20210404
# 834            11   -10   114                   1               1   20210404
# 835            26  -158   211                   1               1   20210404
# 836             1    -3    13                   1               1   20210404
# 837            12   -16   121                   1               1   20210404
# 838            19   -91   167                   1               0   20210404
# 839             1    -6     8                   1               1   20210404
# 840             2     1    21                   1               1   20210404
# 841             0    -5     7                   1               0   20210404
# 842            10    68    81                   1               1   20210404
# 843            25   193   172                   1               0   20210404
# 844            20   179   100                   1               1   20210404
# 845            26   -93   246                   1               0   20210404
# 846             7     4    71                   1               1   20210404
# 847            25    16   259                   1               0   20210404
# 848            25    90   238                   1               1   20210404
# 849            24   200   147                   1               0   20210404
# 850            26   -41   265                   1               1   20210404
# 851            24    31   246                   1               0   20210404
# 852             1     4    15                   1               1   20210404
# 853            26  -186   191                   1               0   20210404
# 854            26  -125   237                   1               0   20210404
#
#      HTM  VTM
# 832  ATL  GSW
# 833  ATL  GSW
# 834  ATL  GSW
# 835  ATL  GSW
# 836  ATL  GSW
# 837  ATL  GSW
# 838  ATL  GSW
# 839  ATL  GSW
# 840  ATL  GSW
# 841  ATL  GSW
# 842  ATL  GSW
# 843  ATL  GSW
# 844  ATL  GSW
# 845  ATL  GSW
# 846  ATL  GSW
# 847  ATL  GSW
# 848  ATL  GSW
# 849  ATL  GSW
# 850  ATL  GSW
# 851  ATL  GSW
# 852  ATL  GSW
# 853  ATL  GSW
# 854  ATL  GSW
#
# [23 rows x 24 columns]

# %%
def court(ax, color):
    
    ax.plot([-220, -220], [0, 140], linewidth=1, color=color)
    ax.plot([220, 220], [0, 140], linewidth=1, color=color)
    
    ax.add_artist(mpl.patches.Arc((0, 140), 440, 315, theta1=0, theta2=180, facecolor='none', edgecolor=color, lw=1))
    
    ax.plot([-80, -80], [0, 190], linewidth=1, color=color)
    ax.plot([80, 80], [0, 190], linewidth=1, color=color)
    ax.plot([-60, -60], [0, 190], linewidth=1, color=color)
    ax.plot([60, 60], [0, 190], linewidth=1, color=color)
    ax.plot([-80, 80], [190, 190], linewidth=1, color=color)
    
    ax.add_artist(mpl.patches.Circle((0, 190), 60, facecolor='none', edgecolor=color, lw=1))
              
    ax.set_xticks([])
    ax.set_yticks([])
    
    ax.set_xlim(-250, 250)
    ax.set_ylim(0, 470)
    
    return ax

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_axes([0, 0, 1, 1])
ax = court(ax, 'black')
ax.scatter(curry['LOC_X'], curry['LOC_Y'] + 65)

plt.show()
